# %% [markdown]
# # Web Scraping Lab
#
# You will find in this notebook some scrapy exercises to practise your scraping skills.
#
# **Tips:**
#
# - Check the response status code for each request to ensure you have obtained the intended content.
# - Print the response text in each request to understand the kind of info you are getting and its format.
# - Check for patterns in the response text to extract the data/info requested in each question.
# - Visit the urls below and take a look at their source code through Chrome DevTools. You'll need to identify the html tags, special class names, etc used in the html content you are expected to extract.
#
# **Resources**:
# - [Requests library](http://docs.python-requests.org/en/master/#the-user-guide)
# - [Beautiful Soup Doc](https://www.crummy.com/software/BeautifulSoup/bs4/doc/)
# - [Urllib](https://docs.python.org/3/library/urllib.html#module-urllib)
# - [re lib](https://docs.python.org/3/library/re.html)
# - [lxml lib](https://lxml.de/)
# - [Scrapy](https://scrapy.org/)
# - [List of HTTP status codes](https://en.wikipedia.org/wiki/List_of_HTTP_status_codes)
# - [HTML basics](http://www.simplehtmlguide.com/cheatsheet.php)
# - [CSS basics](https://www.cssbasics.com/#page_start)

# %% [markdown]
# #### Below are the libraries and modules you may need. `requests`,  `BeautifulSoup` and `pandas` are already imported for you. If you prefer to use additional libraries feel free to do it.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %% [markdown]
# #### Download, parse (using BeautifulSoup), and print the content from the Trending Developers page from GitHub:

# %%
# This is the url you will scrape in this exercise
url = 'https://github.com/trending/developers'

# %%
# your code here
html = requests.get(url).content
print(html[0:600])
# Out:
# b'\n\n\n\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n\n\n\n  <link cr'

# %%
soup = BeautifulSoup(html, "lxml")
soup
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-902658d7af6abf3a6591f6af4f1964d9.css" integrity="sha512-kCZY169qvzplkfavTxlk2YsSPng9uWCnj9G42mBqOwOHPZUivSlgl3kHddDYqj1hZEzZK/GzwIvnG5fGjlpaOw==" media="all" rel="stylesheet"/>
# ...

# %% [markdown]
# #### Display the names of the trending developers retrieved in the previous step.
#
# Your output should be a Python list of developer names. Each name should not contain any html tag.
#
# **Instructions:**
#
# 1. Find out the html tag and class names used for the developer names. You can achieve this using Chrome DevTools.
#
# 1. Use BeautifulSoup to extract all the html elements that contain the developer names.
#
# 1. Use string manipulation techniques to replace whitespaces and linebreaks (i.e. `\n`) in the *text* of each html element. Use a list to store the clean names.
#
# 1. Print the list of names.
#
# Your output should look like below:
#
# ```
# ['trimstray (@trimstray)',
#  'joewalnes (JoeWalnes)',
#  'charlax (Charles-AxelDein)',
#  'ForrestKnight (ForrestKnight)',
#  'revery-ui (revery-ui)',
#  'alibaba (Alibaba)',
#  'Microsoft (Microsoft)',
#  'github (GitHub)',
#  'facebook (Facebook)',
#  'boazsegev (Bo)',
#  'google (Google)',
#  'cloudfetch',
#  'sindresorhus (SindreSorhus)',
#  'tensorflow',
#  'apache (TheApacheSoftwareFoundation)',
#  'DevonCrawford (DevonCrawford)',
#  'ARMmbed (ArmMbed)',
#  'vuejs (vuejs)',
#  'fastai (fast.ai)',
#  'QiShaoXuan (Qi)',
#  'joelparkerhenderson (JoelParkerHenderson)',
#  'torvalds (LinusTorvalds)',
#  'CyC2018',
#  'komeiji-satori (神楽坂覚々)',
#  'script-8']
#  ```

# %%
# your code hereclass="col-md-6"
#tags = ['div', 'a']

trending_developpers = []
for element in soup.find_all('div', {'class' : 'col-sm-8 d-md-flex'}):
    name = element.find_all('h1')[0].text.replace('\n', '').lstrip().rstrip()
    company = element.find('p').text.replace('\n', '').lstrip().rstrip()
    trending_developpers.append(f'{name} ({company})')
    

trending_developpers
# Out:
# ['Jason Quense (jquense)',
#  'Thibault Duplessis (ornicar)',
#  'PySimpleGUI (PySimpleGUI)',
#  'Seth Vargo (sethvargo)',
#  'Jesse Duffield (jesseduffield)',
#  'Danilo Woznica (danilowoz)',
#  'Stephen Dolan (stedolan)',
#  'Wojciech Maj (wojtekmaj)',
#  'Hiroki Nakayama (Hironsan)',
#  'Henrik Rydgård (hrydgard)',
#  'Dave Henderson (hairyhenderson)',
#  'Eliza Weisman (hawkw)',
#  'Nathan Walker (NathanWalker)',
#  'Omry Yadan (omry)',
#  'Daniel Lemire (lemire)',
#  'Chris Van Pelt (vanpelt)',
#  'Philipp Oppermann (phil-opp)',
#  'Jeff Geerling (geerlingguy)',
#  'Stefan Scherer (StefanScherer)',
#  'Michael Fabian Dirks (Xaymar)',
#  'Juliette (jrfnl)',
#  'Dody Gunawinata (dodyg)',
#  'Mark Erikson (markerikson)',
#  'Matteo Mazzarolo (mmazzarolo)',
#  'Timothy Edmund Crosley (timothycrosley)']

# %% [markdown]
# #### Display the trending Python repositories in GitHub.
#
# The steps to solve this problem is similar to the previous one except that you need to find out the repository names instead of developer names.

# %%
# This is the url you will scrape in this exercise
url_1 = 'https://github.com/trending/python?since=daily'

# %%
# your code here
html_1 = requests.get(url_1).content
print(html[0:600])
# Out:
# b'\n\n\n\n<!DOCTYPE html>\n<html lang="en">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars0.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars1.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars2.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://avatars3.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n\n\n\n  <link cr'

# %%
soup_1 = BeautifulSoup(html_1, "lxml")
soup_1
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <link href="https://github.githubassets.com" rel="dns-prefetch"/>
# <link href="https://avatars0.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars1.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars2.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://avatars3.githubusercontent.com" rel="dns-prefetch"/>
# <link href="https://github-cloud.s3.amazonaws.com" rel="dns-prefetch"/>
# <link href="https://user-images.githubusercontent.com/" rel="dns-prefetch"/>
# <link crossorigin="anonymous" href="https://github.githubassets.com/assets/frameworks-902658d7af6abf3a6591f6af4f1964d9.css" integrity="sha512-kCZY169qvzplkfavTxlk2YsSPng9uWCnj9G42mBqOwOHPZUivSlgl3kHddDYqj1hZEzZK/GzwIvnG5fGjlpaOw==" media="all" rel="stylesheet"/>
# ...

# %%
tags_1 = ['h1', {'class' : 'h3 lh-condensed'}]

text_1 = [element.text.replace('\n', '').replace for element in soup_1.find_all(tags_1)]
#text_1.text.replace('\n','')
text_1
# Out:
# ['Trending',
#  '        floodsung /      Deep-Learning-Papers-Reading-Roadmap ',
#  '        pythonstock /      stock ',
#  '        d2l-ai /      d2l-en ',
#  '        openai /      gym ',
#  '        vt-vl-lab /      3d-photo-inpainting ',
#  '        openai /      baselines ',
#  '        openai /      gpt-2 ',
#  '        Pitt-CSC /      Summer2021-Internships ',
#  '        horovod /      horovod ',
#  '        psf /      black ',
#  '        rusty1s /      pytorch_geometric ',
#  '        ymcui /      Chinese-BERT-wwm ',
#  '        facebookresearch /      swav ',
#  '        minimaxir /      gpt-3-experiments ',
#  '        openai /      spinningup ',
#  '        asciimoo /      searx ',
#  '        timgrossmann /      InstaPy ',
#  '        aws /      aws-cli ',
#  '        deepset-ai /      haystack ',
#  '        sherlock-project /      sherlock ',
#  '        locustio /      locust ',
#  '        home-assistant /      core ',
#  '        mlflow /      mlflow ',
# ...

# %%
trending_repos = []
for element1 in soup_1.find_all('h1', {'class' : "h3 lh-condensed"}):
    repo_owner = element.find('a').text.replace('\n', '').lstrip().rstrip()
    #repo_name = element1.find('p')#.text.replace('\n', '').lstrip().rstrip()
    trending_repos.append(f'{repo_owner})')
    

trending_repos    

#Pénélope's
trending_Python_repositories = []
for element in soup.find_all('h1', {'class' : "h3 lh-condensed"}):
    repo = element.find('a').text.replace('\n', '').lstrip().rstrip()
    trending_Python_repositories.append(f'{repo}')
trending_Python_repositories
# Out:
# ['[<a data-hydro-click=\'{"event_type":"explore.click","payload":{"click_context":"TRENDING_REPOSITORIES_PAGE","click_target":"REPOSITORY","click_visual_representation":"REPOSITORY_NAME_HEADING","actor_id":null,"record_id":70905478,"originating_url":"https://github.com/trending/python?since=daily","user_id":null}}\' data-hydro-click-hmac="322b9a96b6b5f2e6fb35023f343e558a1888456b8e215f1b719ec2aa15be7c8b" href="/floodsung/Deep-Learning-Papers-Reading-Roadmap">\n<svg aria-hidden="true" class="octicon octicon-repo mr-1 text-gray" color="gray" height="16" mr="1" version="1.1" viewbox="0 0 16 16" width="16"><path d="M2 2.5A2.5 2.5 0 014.5 0h8.75a.75.75 0 01.75.75v12.5a.75.75 0 01-.75.75h-2.5a.75.75 0 110-1.5h1.75v-2h-8a1 1 0 00-.714 1.7.75.75 0 01-1.072 1.05A2.495 2.495 0 012 11.5v-9zm10.5-1V9h-8c-.356 0-.694.074-1 .208V2.5a1 1 0 011-1h8zM5 12.25v3.25a.25.25 0 00.4.2l1.45-1.087a.25.25 0 01.3 0L8.6 15.7a.25.25 0 00.4-.2v-3.25a.25.25 0 00-.25-.25h-3.5a.25.25 0 00-.25.25z" fill-rule="evenodd"
# ...

# %%
trending_Python_repositories = []
for element in soup.find_all('h1', {'class' : "h3 lh-condensed"}):
    repo = element.find('a').text.replace('\n', '').lstrip().rstrip()
    trending_Python_repositories.append(f'{repo}')
trending_Python_repositories
# Out:
# ['Jason Quense',
#  'Thibault Duplessis',
#  'PySimpleGUI',
#  'Seth Vargo',
#  'Jesse Duffield',
#  'Danilo Woznica',
#  'Stephen Dolan',
#  'Wojciech Maj',
#  'Hiroki Nakayama',
#  'Henrik Rydgård',
#  'Dave Henderson',
#  'Eliza Weisman',
#  'Nathan Walker',
#  'Omry Yadan',
#  'Daniel Lemire',
#  'Chris Van Pelt',
#  'Philipp Oppermann',
#  'Jeff Geerling',
#  'Stefan Scherer',
#  'Michael Fabian Dirks',
#  'Juliette',
#  'Dody Gunawinata',
#  'Mark Erikson',
#  'Matteo Mazzarolo',
#  'Timothy Edmund Crosley']

# %% [markdown]
# #### Display all the image links from Walt Disney wikipedia page.

# %%
# This is the url you will scrape in this exercise
url_walt = 'https://en.wikipedia.org/wiki/Walt_Disney'
html_walt = requests.get(url_walt).content
print(html_walt[0:600])
# Out:
# b'\n<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>Walt Disney - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"d59c37de-87ab-4375-8510-7e3db7584393","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageNa'

# %%
# your code here
soup_walt = BeautifulSoup(html_walt, "lxml")

# %%
walt = soup_walt.find_all('img')
walt_element = [element['src'].replace('//', '') for element in walt]
#walt_element.replace('\\upload.', '')
#walt_element

# %%
trending_developpers = []
for element in soup.find_all('div', {'class' : 'col-sm-8 d-md-flex'}):
    name = element.find_all('h1')[0].text.replace('\n', '').lstrip().rstrip()
    company = element.find('p').text.replace('\n', '').lstrip().rstrip()
    trending_developpers.append(f'{name} ({company})')
    

trending_developpers

# %% [markdown]
# #### Retrieve an arbitary Wikipedia page of "Python" and create a list of links on that page.

# %%
# This is the url you will scrape in this exercise
url_wikipy ='https://en.wikipedia.org/wiki/Python_(film)'

# %%
# your code here

# %%
html_wikipy = requests.get(url_wikipy).content
soup_wikipy = BeautifulSoup(html_wikipy, "lxml")
wikipy = soup_wikipy.find_all('a', href=True)
wikipy_element = [element['href'] for element in wikipy]
#walt_element.replace('\\upload.', '')
wikipy_element
# Out:
# ['#mw-head',
#  '#searchInput',
#  '/wiki/File:Pythoncover.jpg',
#  '/wiki/Daniel_Knauf',
#  '/wiki/Robert_Englund',
#  '/wiki/Casper_Van_Dien',
#  '/wiki/William_Zabka',
#  '/wiki/Dana_Barron',
#  '/wiki/Wil_Wheaton',
#  '/wiki/Sean_Whalen',
#  '/wiki/Jenny_McCarthy',
#  '/wiki/Gary_Grubbs',
#  '/wiki/Ken_Olandt',
#  '/wiki/Phillip_J._Roth',
#  '#cite_note-1',
#  '/wiki/Made-for-TV',
#  '/wiki/Comedy_horror',
#  '#cite_note-2',
#  '/wiki/Cult_following',
#  '/wiki/William_Zabka',
#  '/wiki/The_Karate_Kid_(1984_film)',
#  '/wiki/Wil_Wheaton',
#  '/wiki/Casper_Van_Dien',
#  '/wiki/Jenny_McCarthy',
#  '/wiki/Keith_Coogan',
#  '/wiki/Robert_Englund',
#  '/wiki/Dana_Barron',
#  '/wiki/David_Bowe_(actor)',
#  '/wiki/Sean_Whalen',
#  '/wiki/Snake',
#  '/wiki/Pythonidae',
#  '/wiki/Los_Angeles',
#  '/wiki/Malibu,_California',
#  '/wiki/Pythons_2',
#  '/wiki/New_Alcatraz',
#  '/wiki/Boa_vs._Python',
#  '#Plot',
#  '#Cast',
#  '#Reception',
#  '#Sequels',
#  '#See_also',
#  '#References',
# ...

# %% [markdown]
# #### Find the number of titles that have changed in the United States Code since its last release point.

# %%
# This is the url you will scrape in this exercise
url_usc = 'http://uscode.house.gov/download/download.shtml'

# %%
# your code here
html_usc = requests.get(url_usc).content

# %%
soup_usc = BeautifulSoup(html_usc, "lxml")

# %%
usc = soup_usc.find_all('div', {'class' : 'usctitlechanged'})
usc_element = [element for element in usc]
#walt_element.replace('\\upload.', '')
len(usc_element)
# Out:
# 1

# %% [markdown]
# #### Find a Python list with the top ten FBI's Most Wanted names.

# %%
# This is the url you will scrape in this exercise
url_fbi = 'https://www.fbi.gov/wanted/topten'

# %%
# your code here
html_fbi = requests.get(url_fbi).content

# %%
soup_fbi = BeautifulSoup(html_fbi, "lxml")

# %%
fbi = soup_fbi.find_all('h3', {'class' : 'title'})
fbi_element = [element.text.strip() for element in fbi]
#replace('\n', '') 
fbi_element
# Out:
# ['ROBERT WILLIAM FISHER',
#  'BHADRESHKUMAR CHETANBHAI PATEL',
#  'ALEJANDRO ROSALES CASTILLO',
#  'ARNOLDO JIMENEZ',
#  'JASON DEREK BROWN',
#  'YASER ABDEL SAID',
#  'ALEXIS FLORES',
#  'EUGENE PALMER',
#  'SANTIAGO VILLALBA MEDEROS',
#  'RAFAEL CARO-QUINTERO']

# %% [markdown]
# ####  Display the 20 latest earthquakes info (date, time, latitude, longitude and region name) by the EMSC as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
#url_eq = 'https://www.emsc-csem.org/Earthquake/'

# %%
# your code here
#html_eq = requests.get(url_eq).content

# %%
html = requests.get(url).content
soup = BeautifulSoup(html, 'html')
tables = soup.find_all('table')
eq_table = tables[3]
t_header = eq_table.find_all('th', {'class': 'th2'})
colnames = [th.text.strip() for th in t_header if th not in [t_header[0], t_header[4], t_header[5], t_header[7]]]
tags = eq_table.find_all('td', {'class': ['tabev1', 'tabev2', 'tabev3', 'tabev5', 'tabev6', 'tb_region']})
rows = [row.text.strip() for row in tags]
data = [[rows[x].replace('earthquake', ''), f'{rows[x+1]}{rows[x+2]}', f'{rows[x+3]}{rows[x+4]}', rows[x+8]] for x in range(0, len(rows), 9)]
df = pd.DataFrame(data, columns=colnames).head(20)
df
# Out:
#                          Date & Time UTC Latitude degrees Longitude degrees  \
# 0       2020-07-25   09:19:29.134min ago           55.11N           158.32W
# 1       2020-07-25   08:59:19.954min ago           38.77N            27.82E
# 2   2020-07-25   08:47:03.51hr 06min ago           46.22N             7.79E
# 3   2020-07-25   08:41:16.01hr 12min ago           66.30N            18.66W
# 4   2020-07-25   08:21:02.41hr 32min ago           38.16N           118.03W
# 5   2020-07-25   08:19:54.81hr 33min ago           36.48N           118.05W
# 6   2020-07-25   08:15:04.01hr 38min ago           51.44N            16.08E
# 7   2020-07-25   07:49:40.32hr 04min ago           36.44N           117.99W
# 8   2020-07-25   07:32:16.82hr 21min ago           43.06N            78.42E
# 9   2020-07-25   07:23:00.02hr 30min ago            7.78S           119.01E
# 10  2020-07-25   07:07:04.12hr 46min ago           56.25N           148.69W
# ...

# %% [markdown]
# #### Count the number of tweets by a given Twitter account.
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the number of tweets for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url_tw = 'https://twitter.com/'

# %%
# your code here
html_tw = requests.get(url_tw).content
soup_tw = BeautifulSoup(html_tw, 'lxml')
tw = soup_tw.find_all('table')

# %% [markdown]
# #### Number of followers of a given twitter account
# Ask the user for the handle (@handle) of a twitter account. You will need to include a ***try/except block*** for account names not found.
# <br>***Hint:*** the program should count the followers for any provided account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here
url = 'https://mobile.twitter.com/'
# your code here
handle = 'AOC'
try:
    r = requests.get(f'{url}{handle}').content
except requests.exceptions.HTTPError as errh:
    print ("Http Error:",errh)
except requests.exceptions.ConnectionError as errc:
    print ("Error Connecting:",errc)
except requests.exceptions.Timeout as errt:
    print ("Timeout Error:",errt)
except requests.exceptions.RequestException as err:
    print ("OOps: Something Else",err)
soup = BeautifulSoup(r, 'html')
followers = ' '.join(soup.find('a', {'href': f'/{handle}/followers'}).text.strip().split('\n'))
followers
# Out:
# '7,873,051  Followers'

# %% [markdown]
# #### List all language names and number of related articles in the order they appear in wikipedia.org.

# %%
# This is the url you will scrape in this exercise
url_wiki = 'https://www.wikipedia.org/'

# %%
# your code here
html_wiki = requests.get(url_wiki).content
soup_wiki = BeautifulSoup(html_wiki, 'lxml')
#wiki = soup_wiki.find_all('table')

# %% [markdown]
# #### A list with the different kind of datasets available in data.gov.uk.

# %%
# This is the url you will scrape in this exercise
url = 'https://data.gov.uk/'

# %%
# your code here

# %% [markdown]
# #### Display the top 10 languages by number of native speakers stored in a pandas dataframe.

# %%
# This is the url you will scrape in this exercise
url = 'https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers'

# %%
# your code here

# %% [markdown]
# ## Bonus
# #### Scrape a certain number of tweets of a given Twitter account.

# %%
# This is the url you will scrape in this exercise 
# You will need to add the account credentials to this url
url = 'https://twitter.com/'

# %%
# your code here

# %% [markdown]
# #### Display IMDB's top 250 data (movie name, initial release, director name and stars) as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise 
url = 'https://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Display the movie name, year and a brief summary of the top 10 random movies (IMDB) as a pandas dataframe.

# %%
#This is the url you will scrape in this exercise
url = 'http://www.imdb.com/chart/top'

# %%
# your code here

# %% [markdown]
# #### Find the live weather report (temperature, wind speed, description and weather) of a given city.

# %%
#https://openweathermap.org/current
city = input('Enter the city: ')
url = 'http://api.openweathermap.org/data/2.5/weather?'+'q='+city+'&APPID=b35975e18dc93725acb092f7272cc6b8&units=metric'

# %%
# your code here

# %% [markdown]
# #### Find the book name, price and stock availability as a pandas dataframe.

# %%
# This is the url you will scrape in this exercise. 
# It is a fictional bookstore created to be scraped. 
url = 'http://books.toscrape.com/'

# %%
# your code here
res = []
for book in soup.find_all('li', {'class': 'col-xs-6 col-sm-4 col-md-3 col-lg-3'}):
    title = book.h3.a['title']
    div_prodprice = book.find('div', {'class': 'product_price'})
    price = div_prodprice.find_all('p')[0].text
    stock = div_prodprice.find_all('p')[1].text.strip()
    res.append([title, price, stock])
res_df = pd.DataFrame(res)
