# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# your code here
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=84&sort=popularity'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
response = requests.get(url, headers ={"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36"})
results = response.json()
results


flattened_data = json_normalize(results)

flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
# /Users/spurda/.pyenv/versions/3.7.7/lib/python3.7/site-packages/ipykernel_launcher.py:7: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   import sys
# /Users/spurda/.pyenv/versions/3.7.7/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if __name__ == '__main__':
#               sku                                               name  \
# 0   PI915O004-E11                            Baskets basses - yellow
# 1   JA212G00V-O11                     JFWCROXTON  - Chaussons - java
# 2   LE222S02W-Q11  AUTHENTIC LOGO CREWNECK - Sweatshirt - mineral...
# 3   TOB52N00D-K11              COOL CITY BACKPACK - Sac à dos - blue
# 4   PI922Q00S-K11                                  Gilet - dark blue
# ..            ...                                                ...
# 79  BL522E00R-K11             BHNATAN PANTS - Chino - dark navy blue
# 80  PI922Q00A-C11                       Pullover - dark grey melange
# 81  IJ022F00I-C11                    CASUAL FIT - Short - light grey
# 82  N1242E1DK-Q12  DRY ACADEMY PANT - Pantalon de survêtement - b...
# 83  IJ022F02V-Q11                       MOSTOLES - Short - dark grey
#
#                                                 sizes  \
# 0                [38, 39, 40, 41, 42, 43, 44, 45, 46]
# 1                                [40, 42, 43, 44, 45]
# 2                                  [S, M, L, XL, XXL]
# 3                                          [One Size]
# 4                         [XS, S, M, L, XL, XXL, 3XL]
# ..                                                ...
# 79  [29x32, 30x34, 33x32, 33x34, 34x32, 34x34, 36x...
# 80         [XS, S, M, L, XL, XXL, 3XL, 4XL, 5XL, 6XL]
# 81                                     [XL, XXL, 3XL]
# 82                                    [M, L, XL, XXL]
# 83                                    [S, L, XL, XXL]
#
#                                               url_key  \
# 0        pier-one-baskets-basses-yellow-pi915o004-e11
# 1   jack-and-jones-jfwcroxton-mules-java-ja212g00v...
# 2   levisr-authentic-logo-crewneck-sweatshirt-le22...
# 3   tommy-jeans-cool-city-backpack-sac-a-dos-tob52...
# 4              pier-one-gilet-dark-blue-pi922q00s-k11
# ..                                                ...
# 79  blend-bhnatan-pants-chino-dark-navy-blue-bl522...
# 80               pier-one-pullover-gris-pi922q00a-c11
# 81    indicode-jeans-70-039s-cuba-short-ij022f00i-c11
# 82  nike-performance-dry-academy-pant-pantalon-de-...
# 83       indicode-jeans-short-dark-grey-ij022f02v-q11
#
#                                                 media        brand_name  \
# 0   [{'path': 'PI/91/5O/00/4E/11/PI915O004-E11@2.j...          Pier One
# 1   [{'path': 'JA/21/2G/00/VO/11/JA212G00V-O11@8.j...      Jack & Jones
# 2   [{'path': 'LE/22/2S/02/WQ/11/LE222S02W-Q11@4.j...           Levi's®
# 3   [{'path': 'TO/B5/2N/00/DK/11/TOB52N00D-K11@8.1...       Tommy Jeans
# 4   [{'path': 'PI/92/2Q/00/SK/11/PI922Q00S-K11@18....          Pier One
# ..                                                ...               ...
# 79  [{'path': 'BL/52/2E/00/RK/11/BL522E00R-K11@9.j...             Blend
# 80  [{'path': 'PI/92/2Q/00/AC/11/PI922Q00A-C11@17....          Pier One
# 81  [{'path': 'IJ/02/2F/00/IC/11/IJ022F00I-C11@43....    INDICODE JEANS
# 82  [{'path': 'N1/24/2E/1D/KQ/12/N1242E1DK-Q12@12....  Nike Performance
# 83  [{'path': 'IJ/02/2F/02/VQ/11/IJ022F02V-Q11@11....    INDICODE JEANS
#
#     is_premium                                    family_articles  \
# 0        False  [{'sku': 'PI915O004-E11', 'url_key': 'pier-one...
# 1        False  [{'sku': 'JA212G00V-O11', 'url_key': 'jack-and...
# 2        False  [{'sku': 'LE222S02W-Q11', 'url_key': 'levisr-a...
# 3        False  [{'sku': 'TOB52N00D-K11', 'url_key': 'tommy-je...
# 4        False  [{'sku': 'PI922Q00S-K11', 'url_key': 'pier-one...
# ..         ...                                                ...
# 79       False  [{'sku': 'BL522E00R-K11', 'url_key': 'blend-bh...
# 80       False  [{'sku': 'PI922Q00A-C11', 'url_key': 'pier-one...
# 81       False  [{'sku': 'IJ022F00I-C11', 'url_key': 'indicode...
# 82       False  [{'sku': 'N1242E1DK-Q12', 'url_key': 'nike-per...
# 83       False  [{'sku': 'IJ022F02V-Q11', 'url_key': 'indicode...
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': '-35%', 'tra...          shoe
# 1   [{'key': 'discountRate', 'value': 'Jusqu’à -45...          shoe
# 2   [{'key': 'discountRate', 'value': 'Jusqu’à -60...      clothing
# 3   [{'key': 'discountRate', 'value': '-50%', 'tra...   accessoires
# 4   [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': '-25%', 'tra...      clothing
# 80  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 81  [{'key': 'discountRate', 'value': '-8%', 'trac...      clothing
# 82  [{'key': 'discountRate', 'value': '-60%', 'tra...      clothing
# 83  [{'key': 'discountRate', 'value': '-60%', 'tra...      clothing
#
#    delivery_promises price.original price.promotional  \
# 0                 []        17,99 €           11,69 €
# 1                 []        39,99 €           21,99 €
# 2                 []        69,95 €           27,95 €
# 3                 []        69,95 €           34,95 €
# 4                 []        29,99 €           23,99 €
# ..               ...            ...               ...
# 79                []        39,95 €           29,95 €
# 80                []        22,99 €           18,39 €
# 81                []        39,95 €           36,95 €
# 82                []        49,95 €           19,95 €
# 83                []        39,95 €           15,95 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                         True                                False
# 2                         True                                False
# 3                        False                                False
# 4                        False                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                       False                                False
# 81                       False                                False
# 82                       False                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                     True
# 2                                     True
# 3                                    False
# 4                                    False
# ..                                     ...
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only amount outfits
# 0                                       False    NaN     NaN
# 1                                       False    NaN     NaN
# 2                                       False    NaN     NaN
# 3                                       False    NaN     NaN
# 4                                       False    NaN     NaN
# ..                                        ...    ...     ...
# 79                                      False    NaN     NaN
# 80                                      False    NaN     NaN
# 81                                      False    NaN     NaN
# 82                                      False    NaN     NaN
# 83                                      False    NaN     NaN
#
# [84 rows x 19 columns]

# %%
flattened_data
# Out:
#    total_count        sort                                           articles  \
# 0        73548  popularity  [{'sku': 'PI915O004-E11', 'name': 'Baskets bas...
#
#           query_path previous_page_path     next_page_path page_gender  \
# 0  /promo-homme/?p=2      /promo-homme/  /promo-homme/?p=3         men
#
#    premium                                            filters  \
# 0    False  [{'key': 'sizes', 'label': 'Taille', 'url_key'...
#
#    total_article_count  ...  \
# 0                73553  ...
#
#   teaser.content.tracking_data.cf_tracking_params.adId  \
# 0                                        M7D5hLjAQx2
#
#   teaser.content.tracking_data.cf_tracking_params.slot_id  \
# 0               21672e65-4b93-4cd0-9943-404c19eece9a
#
#   teaser.content.tracking_data.cf_tracking_params.flow_id  \
# 0                                   5JHNUA0JQTX1zD5O
#
#   teaser.content.tracking_data.cf_tracking_params.price  \
# 0                                           0.009044
#
#    teaser.content.tracking_data.cf_tracking_params.campaign_source_id  \
# 0                                        Sfkbd1JvS8m
#
#   teaser.content.tracking_data.cf_tracking_params.request_id  \
# 0               9c65f41c-df41-4716-b771-a376cba1aa82
#
#   teaser.content.tracking_data.cf_tracking_params.campaign_id  \
# 0               32d98882-7460-41a5-92ce-9b20dc292125
#
#                         teaser.content.click_url teaser.channel_name  \
# 0  https://www.zalando.fr/promo-homme/&Sale=True                  CF
#
#                          teaser.slot_id
# 0  21672e65-4b93-4cd0-9943-404c19eece9a
#
# [1 rows x 185 columns]

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']
print(total_pages)
# Out:
# 892

# %%
import time

# %%
# Your code
#df=pd.DataFrame()
for i in range(786, total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset={k}&sort=popularity'
    response = requests.get(url, headers ={"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36"})
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)
    if i%10==0
        print i

df
# Out:
# /Users/spurda/.pyenv/versions/3.7.7/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#
# /Users/spurda/.pyenv/versions/3.7.7/lib/python3.7/site-packages/ipykernel_launcher.py:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if __name__ == '__main__':
#                                                             name  \
# sku
# N1242D2VB-K11  DRY YOGA - T-shirt basique - deep royal blue/b...
# PI982F01L-A11                       5 PACK - Chaussettes - white
# PI982F02B-Q11                       3 PACK - Chaussettes - black
# RE542E0IT-K11  TRAINING ESSENTIALS LINEAR LOGO JOGGERS - Pant...
# TO122P03I-K11                      SLIM FIT - Polo - sky captain
# ...                                                          ...
# PUC22T0CU-O11                         Veste d'hiver - dark brown
# PUC22Q055-C11        MIT VOLLPATENTMUSTER - Pullover - dark grey
# JA222O2IG-A11  JORENZU TEE CREW NECK - T-shirt imprimé - clou...
# JA222O2I7-A11  JOROCEANSIDE TEE CREW NECK SLIM FIT - T-shirt ...
# RI922T03A-G11                         Veste de survêtement - red
#
#                                 sizes  \
# sku
# N1242D2VB-K11               [S, M, L]
# PI982F01L-A11          [39-42, 43-46]
# PI982F02B-Q11          [39-42, 43-46]
# RE542E0IT-K11  [XS, S, M, L, XL, XXL]
# TO122P03I-K11      [S, M, L, XL, XXL]
# ...                               ...
# PUC22T0CU-O11                     [L]
# PUC22Q055-C11                     [S]
# JA222O2IG-A11                     [S]
# JA222O2I7-A11                     [S]
# RI922T03A-G11                    [XS]
#
#                                                          url_key  \
# sku
# N1242D2VB-K11  nike-performance-m-nk-dry-top-ss-t-shirt-basiq...
# PI982F01L-A11    pier-one-5-pack-chaussettes-white-pi982f01l-a11
# PI982F02B-Q11          pier-one-3-pack-chaussettes-pi982f02b-q11
# RE542E0IT-K11  reebok-training-essentials-linear-logo-joggers...
# TO122P03I-K11      tommy-hilfiger-polo-sky-captain-to122p03i-k11
# ...                                                          ...
# PUC22T0CU-O11  pullandbear-veste-dhiver-dark-brown-puc22t0cu-o11
# PUC22Q055-C11  pullandbear-mit-vollpatentmuster-pullover-dark...
# JA222O2IG-A11  jack-and-jones-jorenzu-tee-crew-neck-t-shirt-i...
# JA222O2I7-A11  jack-and-jones-joroceanside-tee-crew-neck-slim...
# RI922T03A-G11  river-island-veste-de-survetement-red-ri922t03...
#
#                                                            media  \
# sku
# N1242D2VB-K11  [{'path': 'N1/24/2D/2V/BK/11/N1242D2VB-K11@12....
# PI982F01L-A11  [{'path': 'PI/98/2F/01/LA/11/PI982F01L-A11@3.j...
# PI982F02B-Q11  [{'path': 'PI/98/2F/02/BQ/11/PI982F02B-Q11@5.j...
# RE542E0IT-K11  [{'path': 'RE/54/2E/0I/TK/11/RE542E0IT-K11@18....
# TO122P03I-K11  [{'path': 'TO/12/2P/03/IK/11/TO122P03I-K11@13....
# ...                                                          ...
# PUC22T0CU-O11  [{'path': 'PU/C2/2T/0C/UO/11/PUC22T0CU-O11@20....
# PUC22Q055-C11  [{'path': 'PU/C2/2Q/05/5C/11/PUC22Q055-C11@13....
# JA222O2IG-A11  [{'path': 'JA/22/2O/2I/GA/11/JA222O2IG-A11@4.1...
# JA222O2I7-A11  [{'path': 'JA/22/2O/2I/7A/11/JA222O2I7-A11@16....
# RI922T03A-G11  [{'path': 'RI/92/2T/03/AG/11/RI922T03A-G11@4.j...
#
#                      brand_name  is_premium  \
# sku
# N1242D2VB-K11  Nike Performance       False
# PI982F01L-A11          Pier One       False
# PI982F02B-Q11          Pier One       False
# RE542E0IT-K11            Reebok       False
# TO122P03I-K11    Tommy Hilfiger       False
# ...                         ...         ...
# PUC22T0CU-O11         PULL&BEAR       False
# PUC22Q055-C11         PULL&BEAR       False
# JA222O2IG-A11      Jack & Jones       False
# JA222O2I7-A11      Jack & Jones       False
# RI922T03A-G11      River Island       False
#
#                                                  family_articles  \
# sku
# N1242D2VB-K11                                                 []
# PI982F01L-A11                                                 []
# PI982F02B-Q11                                                 []
# RE542E0IT-K11                                                 []
# TO122P03I-K11                                                 []
# ...                                                          ...
# PUC22T0CU-O11  [{'sku': 'PUC22T0CU-O11', 'url_key': 'pullandb...
# PUC22Q055-C11  [{'sku': 'PUC22Q055-C11', 'url_key': 'pullandb...
# JA222O2IG-A11  [{'sku': 'JA222O2IG-A11', 'url_key': 'jack-and...
# JA222O2I7-A11  [{'sku': 'JA222O2I7-A11', 'url_key': 'jack-and...
# RI922T03A-G11  [{'sku': 'RI922T03A-G11', 'url_key': 'river-is...
#
#                                                            flags  \
# sku
# N1242D2VB-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# PI982F01L-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# PI982F02B-Q11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# RE542E0IT-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# TO122P03I-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# ...                                                          ...
# PUC22T0CU-O11                                                 []
# PUC22Q055-C11                                                 []
# JA222O2IG-A11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
# JA222O2I7-A11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
# RI922T03A-G11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
#
#               product_group delivery_promises  ...  \
# sku                                            ...
# N1242D2VB-K11      clothing                []  ...
# PI982F01L-A11     underwear                []  ...
# PI982F02B-Q11     underwear                []  ...
# RE542E0IT-K11      clothing                []  ...
# TO122P03I-K11      clothing                []  ...
# ...                     ...               ...  ...
# PUC22T0CU-O11      clothing                []  ...
# PUC22Q055-C11      clothing                []  ...
# JA222O2IG-A11      clothing                []  ...
# JA222O2I7-A11      clothing                []  ...
# RI922T03A-G11      clothing                []  ...
#
#               price.has_different_promotional_prices  \
# sku
# N1242D2VB-K11                                  False
# PI982F01L-A11                                  False
# PI982F02B-Q11                                  False
# RE542E0IT-K11                                  False
# TO122P03I-K11                                  False
# ...                                              ...
# PUC22T0CU-O11                                  False
# PUC22Q055-C11                                  False
# JA222O2IG-A11                                  False
# JA222O2I7-A11                                  False
# RI922T03A-G11                                  False
#
#               price.has_discount_on_selected_sizes_only  \
# sku
# N1242D2VB-K11                                     False
# PI982F01L-A11                                     False
# PI982F02B-Q11                                     False
# RE542E0IT-K11                                     False
# TO122P03I-K11                                     False
# ...                                                 ...
# PUC22T0CU-O11                                     False
# PUC22Q055-C11                                     False
# JA222O2IG-A11                                     False
# JA222O2I7-A11                                     False
# RI922T03A-G11                                     False
#
#                     tracking_information.metrigo_impression_urls  \
# sku
# N1242D2VB-K11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# PI982F01L-A11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# PI982F02B-Q11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# RE542E0IT-K11                                                NaN
# TO122P03I-K11                                                NaN
# ...                                                          ...
# PUC22T0CU-O11                                                NaN
# PUC22Q055-C11                                                NaN
# JA222O2IG-A11                                                NaN
# JA222O2I7-A11                                                NaN
# RI922T03A-G11                                                NaN
#
#                           tracking_information.impression_beacon  \
# sku
# N1242D2VB-K11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# PI982F01L-A11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# PI982F02B-Q11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# RE542E0IT-K11                                                NaN
# TO122P03I-K11                                                NaN
# ...                                                          ...
# PUC22T0CU-O11                                                NaN
# PUC22Q055-C11                                                NaN
# JA222O2IG-A11                                                NaN
# JA222O2I7-A11                                                NaN
# RI922T03A-G11                                                NaN
#
#                tracking_information.source  outfits amount price.base_price  \
# sku
# N1242D2VB-K11                          ccp      NaN    NaN              NaN
# PI982F01L-A11                          ccp      NaN    NaN              NaN
# PI982F02B-Q11                          ccp      NaN    NaN              NaN
# RE542E0IT-K11                          NaN      NaN    NaN              NaN
# TO122P03I-K11                          NaN      NaN    NaN              NaN
# ...                                    ...      ...    ...              ...
# PUC22T0CU-O11                          NaN      NaN    NaN              NaN
# PUC22Q055-C11                          NaN      NaN    NaN              NaN
# JA222O2IG-A11                          NaN      NaN    NaN              NaN
# JA222O2I7-A11                          NaN      NaN    NaN              NaN
# RI922T03A-G11                          NaN      NaN    NaN              NaN
#
#               condition condition_key
# sku
# N1242D2VB-K11       NaN           NaN
# PI982F01L-A11       NaN           NaN
# PI982F02B-Q11       NaN           NaN
# RE542E0IT-K11       NaN           NaN
# TO122P03I-K11       NaN           NaN
# ...                 ...           ...
# PUC22T0CU-O11       NaN           NaN
# PUC22Q055-C11       NaN           NaN
# JA222O2IG-A11       NaN           NaN
# JA222O2I7-A11       NaN           NaN
# RI922T03A-G11       NaN           NaN
#
# [75600 rows x 24 columns]

# %%
df
# Out:
#                                                             name  \
# sku
# N1242D2VB-K11  DRY YOGA - T-shirt basique - deep royal blue/b...
# PI982F01L-A11                       5 PACK - Chaussettes - white
# PI982F02B-Q11                       3 PACK - Chaussettes - black
# RE542E0IT-K11  TRAINING ESSENTIALS LINEAR LOGO JOGGERS - Pant...
# TO122P03I-K11                      SLIM FIT - Polo - sky captain
# ...                                                          ...
# PUC22T0CU-O11                         Veste d'hiver - dark brown
# PUC22Q055-C11        MIT VOLLPATENTMUSTER - Pullover - dark grey
# JA222O2IG-A11  JORENZU TEE CREW NECK - T-shirt imprimé - clou...
# JA222O2I7-A11  JOROCEANSIDE TEE CREW NECK SLIM FIT - T-shirt ...
# RI922T03A-G11                         Veste de survêtement - red
#
#                                 sizes  \
# sku
# N1242D2VB-K11               [S, M, L]
# PI982F01L-A11          [39-42, 43-46]
# PI982F02B-Q11          [39-42, 43-46]
# RE542E0IT-K11  [XS, S, M, L, XL, XXL]
# TO122P03I-K11      [S, M, L, XL, XXL]
# ...                               ...
# PUC22T0CU-O11                     [L]
# PUC22Q055-C11                     [S]
# JA222O2IG-A11                     [S]
# JA222O2I7-A11                     [S]
# RI922T03A-G11                    [XS]
#
#                                                          url_key  \
# sku
# N1242D2VB-K11  nike-performance-m-nk-dry-top-ss-t-shirt-basiq...
# PI982F01L-A11    pier-one-5-pack-chaussettes-white-pi982f01l-a11
# PI982F02B-Q11          pier-one-3-pack-chaussettes-pi982f02b-q11
# RE542E0IT-K11  reebok-training-essentials-linear-logo-joggers...
# TO122P03I-K11      tommy-hilfiger-polo-sky-captain-to122p03i-k11
# ...                                                          ...
# PUC22T0CU-O11  pullandbear-veste-dhiver-dark-brown-puc22t0cu-o11
# PUC22Q055-C11  pullandbear-mit-vollpatentmuster-pullover-dark...
# JA222O2IG-A11  jack-and-jones-jorenzu-tee-crew-neck-t-shirt-i...
# JA222O2I7-A11  jack-and-jones-joroceanside-tee-crew-neck-slim...
# RI922T03A-G11  river-island-veste-de-survetement-red-ri922t03...
#
#                                                            media  \
# sku
# N1242D2VB-K11  [{'path': 'N1/24/2D/2V/BK/11/N1242D2VB-K11@12....
# PI982F01L-A11  [{'path': 'PI/98/2F/01/LA/11/PI982F01L-A11@3.j...
# PI982F02B-Q11  [{'path': 'PI/98/2F/02/BQ/11/PI982F02B-Q11@5.j...
# RE542E0IT-K11  [{'path': 'RE/54/2E/0I/TK/11/RE542E0IT-K11@18....
# TO122P03I-K11  [{'path': 'TO/12/2P/03/IK/11/TO122P03I-K11@13....
# ...                                                          ...
# PUC22T0CU-O11  [{'path': 'PU/C2/2T/0C/UO/11/PUC22T0CU-O11@20....
# PUC22Q055-C11  [{'path': 'PU/C2/2Q/05/5C/11/PUC22Q055-C11@13....
# JA222O2IG-A11  [{'path': 'JA/22/2O/2I/GA/11/JA222O2IG-A11@4.1...
# JA222O2I7-A11  [{'path': 'JA/22/2O/2I/7A/11/JA222O2I7-A11@16....
# RI922T03A-G11  [{'path': 'RI/92/2T/03/AG/11/RI922T03A-G11@4.j...
#
#                      brand_name  is_premium  \
# sku
# N1242D2VB-K11  Nike Performance       False
# PI982F01L-A11          Pier One       False
# PI982F02B-Q11          Pier One       False
# RE542E0IT-K11            Reebok       False
# TO122P03I-K11    Tommy Hilfiger       False
# ...                         ...         ...
# PUC22T0CU-O11         PULL&BEAR       False
# PUC22Q055-C11         PULL&BEAR       False
# JA222O2IG-A11      Jack & Jones       False
# JA222O2I7-A11      Jack & Jones       False
# RI922T03A-G11      River Island       False
#
#                                                  family_articles  \
# sku
# N1242D2VB-K11                                                 []
# PI982F01L-A11                                                 []
# PI982F02B-Q11                                                 []
# RE542E0IT-K11                                                 []
# TO122P03I-K11                                                 []
# ...                                                          ...
# PUC22T0CU-O11  [{'sku': 'PUC22T0CU-O11', 'url_key': 'pullandb...
# PUC22Q055-C11  [{'sku': 'PUC22Q055-C11', 'url_key': 'pullandb...
# JA222O2IG-A11  [{'sku': 'JA222O2IG-A11', 'url_key': 'jack-and...
# JA222O2I7-A11  [{'sku': 'JA222O2I7-A11', 'url_key': 'jack-and...
# RI922T03A-G11  [{'sku': 'RI922T03A-G11', 'url_key': 'river-is...
#
#                                                            flags  \
# sku
# N1242D2VB-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# PI982F01L-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# PI982F02B-Q11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# RE542E0IT-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# TO122P03I-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# ...                                                          ...
# PUC22T0CU-O11                                                 []
# PUC22Q055-C11                                                 []
# JA222O2IG-A11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
# JA222O2I7-A11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
# RI922T03A-G11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
#
#               product_group delivery_promises  ...  \
# sku                                            ...
# N1242D2VB-K11      clothing                []  ...
# PI982F01L-A11     underwear                []  ...
# PI982F02B-Q11     underwear                []  ...
# RE542E0IT-K11      clothing                []  ...
# TO122P03I-K11      clothing                []  ...
# ...                     ...               ...  ...
# PUC22T0CU-O11      clothing                []  ...
# PUC22Q055-C11      clothing                []  ...
# JA222O2IG-A11      clothing                []  ...
# JA222O2I7-A11      clothing                []  ...
# RI922T03A-G11      clothing                []  ...
#
#               price.has_different_promotional_prices  \
# sku
# N1242D2VB-K11                                  False
# PI982F01L-A11                                  False
# PI982F02B-Q11                                  False
# RE542E0IT-K11                                  False
# TO122P03I-K11                                  False
# ...                                              ...
# PUC22T0CU-O11                                  False
# PUC22Q055-C11                                  False
# JA222O2IG-A11                                  False
# JA222O2I7-A11                                  False
# RI922T03A-G11                                  False
#
#               price.has_discount_on_selected_sizes_only  \
# sku
# N1242D2VB-K11                                     False
# PI982F01L-A11                                     False
# PI982F02B-Q11                                     False
# RE542E0IT-K11                                     False
# TO122P03I-K11                                     False
# ...                                                 ...
# PUC22T0CU-O11                                     False
# PUC22Q055-C11                                     False
# JA222O2IG-A11                                     False
# JA222O2I7-A11                                     False
# RI922T03A-G11                                     False
#
#                     tracking_information.metrigo_impression_urls  \
# sku
# N1242D2VB-K11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# PI982F01L-A11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# PI982F02B-Q11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# RE542E0IT-K11                                                NaN
# TO122P03I-K11                                                NaN
# ...                                                          ...
# PUC22T0CU-O11                                                NaN
# PUC22Q055-C11                                                NaN
# JA222O2IG-A11                                                NaN
# JA222O2I7-A11                                                NaN
# RI922T03A-G11                                                NaN
#
#                           tracking_information.impression_beacon  \
# sku
# N1242D2VB-K11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# PI982F01L-A11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# PI982F02B-Q11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# RE542E0IT-K11                                                NaN
# TO122P03I-K11                                                NaN
# ...                                                          ...
# PUC22T0CU-O11                                                NaN
# PUC22Q055-C11                                                NaN
# JA222O2IG-A11                                                NaN
# JA222O2I7-A11                                                NaN
# RI922T03A-G11                                                NaN
#
#                tracking_information.source  outfits amount price.base_price  \
# sku
# N1242D2VB-K11                          ccp      NaN    NaN              NaN
# PI982F01L-A11                          ccp      NaN    NaN              NaN
# PI982F02B-Q11                          ccp      NaN    NaN              NaN
# RE542E0IT-K11                          NaN      NaN    NaN              NaN
# TO122P03I-K11                          NaN      NaN    NaN              NaN
# ...                                    ...      ...    ...              ...
# PUC22T0CU-O11                          NaN      NaN    NaN              NaN
# PUC22Q055-C11                          NaN      NaN    NaN              NaN
# JA222O2IG-A11                          NaN      NaN    NaN              NaN
# JA222O2I7-A11                          NaN      NaN    NaN              NaN
# RI922T03A-G11                          NaN      NaN    NaN              NaN
#
#               condition condition_key
# sku
# N1242D2VB-K11       NaN           NaN
# PI982F01L-A11       NaN           NaN
# PI982F02B-Q11       NaN           NaN
# RE542E0IT-K11       NaN           NaN
# TO122P03I-K11       NaN           NaN
# ...                 ...           ...
# PUC22T0CU-O11       NaN           NaN
# PUC22Q055-C11       NaN           NaN
# JA222O2IG-A11       NaN           NaN
# JA222O2I7-A11       NaN           NaN
# RI922T03A-G11       NaN           NaN
#
# [75600 rows x 24 columns]

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# trending brand
df.brand_name.value_counts().index[0]
# Out:
# 'Jack & Jones'

# %%
#product with the highest discount
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'BOSS'

# %%
#The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices)
