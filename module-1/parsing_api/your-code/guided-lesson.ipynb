# %% [markdown]
# # Parsing APIs Example

# %% [markdown]
# ## Intro
#
# Now we will take a look on a real data. When you parse data from web you will often meet API based web-pages.
#
# For example [zalando.fr](https://www.zalando.fr/accueil-homme/) is API based web-page.
#
# In this guided lab you will learn how to obtain the links from webpages and extract the data. Read through this doc, execute the cells in order and make sure you understand the explanations.
#
# *Note: This guided lab uses Google Chrome. Other browsers like Safari and Firefox have similar tools for developers but they work differently. To save your time in following this lab, it is strongly recommended that you install and use Google Chrome.*

# %% [markdown]
# ## Obtaining the link
#
# Zalando is discount e-store where you can buy clothes and accesories with discount. When we go to the web-page, we can choose different sections. First the general process will be shown using [Children section](https://www.zalando.fr/accueil-enfant/) as example.
#
# Here we will parse data about promotions only. Therefore, final output will be the DataFrame with all the goods under discount.
#
# [![Image from Gyazo](https://i.gyazo.com/fa4874d8e81c7570273bbfb853d66308.png)](https://gyazo.com/fa4874d8e81c7570273bbfb853d66308)
#
#
# We go to Promos page. Right click of mouse shows us a list of actions possible, from which we select Inspect.
#
# <img src='https://i.gyazo.com/bccbd11d69c9040dc98758d443e32052.png' width="400">
#
#
# You will see the menu dropdown on the right side or on the bottom of the window. There you should click on Network:
#
#
# [![Image from Gyazo](https://i.gyazo.com/f7e0db81cbfee67694183d1a7640bf81.png)](https://gyazo.com/f7e0db81cbfee67694183d1a7640bf81)

# %% [markdown]
# Right after the developer part will change showing the files behind the page. In order to obtain only useful files we select the following settings:
# 1. Preserve Log
# 2. Select XHR files.
#
# [![Image from Gyazo](https://i.gyazo.com/9a899d4441d9d93e795f79747f1e47d5.png)](https://gyazo.com/9a899d4441d9d93e795f79747f1e47d5)
#
# In order to obtain some files we need to scrool down and go forward to second page.
#
# [![Image from Gyazo](https://i.gyazo.com/0956eb3d5125075a236c9a439c7749c7.png)](https://gyazo.com/0956eb3d5125075a236c9a439c7749c7)
#
# In the Network panel you can see the following files being uploaded. All the data on the web-page is uploaded from the json file, which is one of the following. It is important to understand which file contains what kind of information.
#
# <a href="https://gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c"><img src="https://i.gyazo.com/cf97a655869f0b22df0ada1cb2a41c3c.png" alt="Image from Gyazo" width="724.8"/></a>
#
# When you find what kind of information you need for the data to be uploaded you just test it. Here we need the article... file:
#
# <a href="https://gyazo.com/78b35bf492994b3f35c0564a21da202a"><img src="https://i.gyazo.com/78b35bf492994b3f35c0564a21da202a.png" alt="Image from Gyazo" width="727.2"/></a>
#
# When we test the link in Chrome inkognito mode we obtain the proper json file:
#
#
# <a href="https://gyazo.com/b60453fa98454fa29771c731a5174443"><img src="https://i.gyazo.com/b60453fa98454fa29771c731a5174443.png" alt="Image from Gyazo" width="1530.4"/></a>

# %% [markdown]
# In order to change the objects in the json file (kind of pagination), you need to change the offset (the number of the first element on the page). in fact, if you take a look on the link, it is easy to unerstand the structure of the link.
#
# # Reading the data
#
# Now the party rocks! When we know how can we obtain the data, it is not a problem to obtain the whole database with all the data from the web-page.
# In this lab you will collect your database of Zalando products. You select which goods you want to track. You can define as many filters to your data as you want. Just make sure that the data represents the filters.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
# Paste the url you obtained for your data
url='https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset=0&sort=sale'

# %% [markdown]
# #### Collect first 84 object of the of the data (1st page)
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having *family_articles, flags, media* and *sizes* remaining lists (they are exceptions).

# %%
data = pd.DataFrame(url)
data.head(84)

# %%
# Your code

response = requests.get(url, headers ={"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36"})
results = response.json()
results


flattened_data = json_normalize(results)

flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
# /Users/spurda/.pyenv/versions/3.7.7/lib/python3.7/site-packages/ipykernel_launcher.py:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#
# /Users/spurda/.pyenv/versions/3.7.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   # Remove the CWD from sys.path while we load stuff.
#               sku                                               name  \
# 0   AD116D0QW-I11  SUPERSTAR  - Baskets basses - purple tint/lege...
# 1   HA113G002-F11                           LUNA - Tongs - rose gold
# 2   WO813D00O-F11              SANDRA - Baskets basses - canyon rose
# 3   NI113D09V-A11  AIR MAX 270 EXTREME - Mocassins - white/ghost ...
# 4   AD123K01P-K11        TREFOIL CREW - Sweatshirt - dark blue/white
# ..            ...                                                ...
# 79  RI923J01A-Q11                                   Pullover - black
# 80  NI126K01J-G11  Veste de survêtement - university red/white/ga...
# 81  NI114D0C1-G11  AIR MAX TAILWIND IV - Baskets basses - univers...
# 82  NI116D050-Q11  AIR MAX 270 REACT - Baskets basses - black/dar...
# 83  N1243D0ZJ-K14  DRY ACADEMY - T-shirt de sport - soar/obsidian...
#
#                                                 sizes  \
# 0                                    [20, 22, 25, 26]
# 1                                      [29/30, 31/32]
# 2            [24, 25, 26, 27, 28, 30, 32, 33, 34, 35]
# 3   [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33.5,...
# 4       [8-9a, 9-10a, 10-11a, 11-12a, 12-13a, 13-14a]
# ..                                                ...
# 79                                      [7-8a, 9-10a]
# 80                        [8-9a, 10-11a, 12-13a, 14a]
# 81                         [36.5, 37.5, 38, 38.5, 39]
# 82                             [36.5, 37.5, 38, 38.5]
# 83                      [6-8a, 8-10a, 10-12a, 12-13a]
#
#                                               url_key  \
# 0   adidas-originals-superstar-baskets-basses-purp...
# 1             havaianas-kids-luna-tongs-ha113g002-f11
# 2     woden-sandra-pearl-baskets-basses-wo813d00o-f11
# 3   nike-sportswear-air-max-270-extreme-baskets-ba...
# 4   adidas-originals-trefoil-crew-sweatshirt-ad123...
# ..                                                ...
# 79          river-island-pullover-black-ri923j01a-q11
# 80  nike-sportswear-veste-de-survetement-universit...
# 81  nike-sportswear-air-max-tailwind-baskets-basse...
# 82  nike-sportswear-air-max-270-react-baskets-bass...
# 83  nike-performance-dry-t-shirt-de-sport-n1243d0z...
#
#                                                 media        brand_name  \
# 0   [{'path': 'AD/11/6D/0Q/WI/11/AD116D0QW-I11@9.j...  adidas Originals
# 1   [{'path': 'HA/11/3G/00/2F/11/HA113G002-F11@11....         Havaianas
# 2   [{'path': 'WO/81/3D/00/OF/11/WO813D00O-F11@3.j...             Woden
# 3   [{'path': 'NI/11/3D/09/VA/11/NI113D09V-A11@7.j...   Nike Sportswear
# 4   [{'path': 'AD/12/3K/01/PK/11/AD123K01P-K11@21....  adidas Originals
# ..                                                ...               ...
# 79  [{'path': 'RI/92/3J/01/AQ/11/RI923J01A-Q11@7.j...      River Island
# 80  [{'path': 'NI/12/6K/01/JG/11/NI126K01J-G11@7.j...   Nike Sportswear
# 81  [{'path': 'NI/11/4D/0C/1G/11/NI114D0C1-G11@6.j...   Nike Sportswear
# 82  [{'path': 'NI/11/6D/05/0Q/11/NI116D050-Q11@3.j...   Nike Sportswear
# 83  [{'path': 'N1/24/3D/0Z/JK/14/N1243D0ZJ-K14@7.j...  Nike Performance
#
#     is_premium                                    family_articles  \
# 0        False  [{'sku': 'AD116D0QW-I11', 'url_key': 'adidas-o...
# 1        False  [{'sku': 'HA113G002-F11', 'url_key': 'havaiana...
# 2        False  [{'sku': 'WO813D00O-F11', 'url_key': 'woden-sa...
# 3        False  [{'sku': 'NI113D09V-A11', 'url_key': 'nike-spo...
# 4        False  [{'sku': 'AD123K01P-K11', 'url_key': 'adidas-o...
# ..         ...                                                ...
# 79       False  [{'sku': 'RI923J01A-Q11', 'url_key': 'river-is...
# 80       False  [{'sku': 'NI126K01J-G11', 'url_key': 'nike-spo...
# 81       False  [{'sku': 'NI114D0C1-G11', 'url_key': 'nike-spo...
# 82       False  [{'sku': 'NI116D050-Q11', 'url_key': 'nike-spo...
# 83       False  [{'sku': 'N1243D0ZJ-K14', 'url_key': 'nike-per...
#
#                                                 flags product_group  \
# 0   [{'key': 'campaign', 'value': '-15% EXTRA', 't...          shoe
# 1   [{'key': 'campaign', 'value': '-15% EXTRA', 't...          shoe
# 2   [{'key': 'campaign', 'value': '-15% EXTRA', 't...          shoe
# 3   [{'key': 'campaign', 'value': '-15% EXTRA', 't...          shoe
# 4   [{'key': 'campaign', 'value': '-15% EXTRA', 't...      clothing
# ..                                                ...           ...
# 79  [{'key': 'campaign', 'value': '-15% EXTRA', 't...      clothing
# 80  [{'key': 'campaign', 'value': '-15% EXTRA', 't...      clothing
# 81  [{'key': 'campaign', 'value': '-15% EXTRA', 't...          shoe
# 82  [{'key': 'campaign', 'value': '-15% EXTRA', 't...          shoe
# 83  [{'key': 'campaign', 'value': '-15% EXTRA', 't...      clothing
#
#    delivery_promises price.original price.promotional  \
# 0                 []        54,95 €           41,45 €
# 1                 []        19,95 €           17,95 €
# 2                 []        69,95 €           38,45 €
# 3                 []        89,95 €           35,95 €
# 4                 []        37,95 €           15,15 €
# ..               ...            ...               ...
# 79                []        23,00 €            9,30 €
# 80                []        49,95 €           22,45 €
# 81                []       139,95 €           62,95 €
# 82                []       129,95 €           51,95 €
# 83                []        14,95 €           11,25 €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                        False                                False
# 2                         True                                False
# 3                        False                                False
# 4                         True                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                        True                                False
# 81                       False                                False
# 82                       False                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                     True
# 3                                    False
# 4                                     True
# ..                                     ...
# 79                                   False
# 80                                    True
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only  \
# 0                                       False
# 1                                       False
# 2                                       False
# 3                                       False
# 4                                       False
# ..                                        ...
# 79                                      False
# 80                                      False
# 81                                      False
# 82                                      False
# 83                                      False
#
#          tracking_information.metrigo_impression_urls  \
# 0   [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# 1   [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# 2   [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
#                tracking_information.impression_beacon  \
# 0   https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# 1   https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# 2   https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
#    tracking_information.source
# 0                          ccp
# 1                          ccp
# 2                          ccp
# 3                          NaN
# 4                          NaN
# ..                         ...
# 79                         NaN
# 80                         NaN
# 81                         NaN
# 82                         NaN
# 83                         NaN
#
# [84 rows x 20 columns]

# %% [markdown]
# #### Collect all the objects from selected filters. Total number of pages can be found in the same json. Use *sku* column as index.
#
# Your output should be a Pandas DataFrame of goods. Each row should contain only text or numbers, having family_articles, flags, media and sizes remaining lists (they are exceptions).

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']

# Your code
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    response = requests.get(url, headers ={"user-agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.116 Safari/537.36"})
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

df
# Out:
# /Users/spurda/.pyenv/versions/3.7.7/lib/python3.7/site-packages/ipykernel_launcher.py:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   # This is added back by InteractiveShellApp.init_path()
# /Users/spurda/.pyenv/versions/3.7.7/lib/python3.7/site-packages/ipykernel_launcher.py:12: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   if sys.path[0] == '':
#                                                             name  \
# sku
# LE213D004-K11             SPRINGFIELD - Mocassins - navy/red/blu
# AD116D0QW-I11  SUPERSTAR  - Baskets basses - purple tint/lege...
# HA113G002-F11                           LUNA - Tongs - rose gold
# NI113D09V-A11  AIR MAX 270 EXTREME - Mocassins - white/ghost ...
# AD123K01P-K11        TREFOIL CREW - Sweatshirt - dark blue/white
# ...                                                          ...
# EW383D04U-C11    STERNE GLITZER 2 PACK - Collants - grau melange
# JH186B00D-T11                NIGHTSUIT - Pyjama - multi-coloured
# FA183D028-K11                      FAIR ISLE - Collants - marine
# FA183D027-J11                  GLITTER DOT - Collants - flamingo
# FA183D020-I11                    MULTI STRIPE - Collants - lilac
#
#                                                            sizes  \
# sku
# LE213D004-K11                           [30, 31, 32, 33, 34, 35]
# AD116D0QW-I11                                   [20, 22, 25, 26]
# HA113G002-F11                              [27/28, 29/30, 31/32]
# NI113D09V-A11  [27.5, 28, 28.5, 29.5, 30, 31, 31.5, 32, 33.5,...
# AD123K01P-K11      [8-9a, 9-10a, 10-11a, 11-12a, 12-13a, 13-14a]
# ...                                                          ...
# EW383D04U-C11                                      [3-4a, 9-10a]
# JH186B00D-T11                                             [0-1m]
# FA183D028-K11                                             [7-8a]
# FA183D027-J11                                           -2a]
# FA183D020-I11                                             [3-6m]
#
#                                                          url_key  \
# sku
# LE213D004-K11     levisr-baskets-basses-navyredblu-le213d004-k11
# AD116D0QW-I11  adidas-originals-superstar-baskets-basses-purp...
# HA113G002-F11            havaianas-kids-luna-tongs-ha113g002-f11
# NI113D09V-A11  nike-sportswear-air-max-270-extreme-baskets-ba...
# AD123K01P-K11  adidas-originals-trefoil-crew-sweatshirt-ad123...
# ...                                                          ...
# EW383D04U-C11  ewers-sterne-glitzer-2-pack-collants-grau-mela...
# JH186B00D-T11  joha-nightsuit-pyjama-multi-coloured-jh186b00d...
# FA183D028-K11      falke-fair-isle-collants-marine-fa183d028-k11
# FA183D027-J11  falke-glitter-dot-collants-flamingo-fa183d027-j11
# FA183D020-I11    falke-multi-stripe-collants-lilac-fa183d020-i11
#
#                                                            media  \
# sku
# LE213D004-K11  [{'path': 'LE/21/3D/00/4K/11/LE213D004-K11@8.1...
# AD116D0QW-I11  [{'path': 'AD/11/6D/0Q/WI/11/AD116D0QW-I11@9.j...
# HA113G002-F11  [{'path': 'HA/11/3G/00/2F/11/HA113G002-F11@11....
# NI113D09V-A11  [{'path': 'NI/11/3D/09/VA/11/NI113D09V-A11@7.j...
# AD123K01P-K11  [{'path': 'AD/12/3K/01/PK/11/AD123K01P-K11@21....
# ...                                                          ...
# EW383D04U-C11  [{'path': 'EW/38/3D/04/UC/11/EW383D04U-C11@11....
# JH186B00D-T11  [{'path': 'JH/18/6B/00/DT/11/JH186B00D-T11@2.j...
# FA183D028-K11  [{'path': 'FA/18/3D/02/8K/11/FA183D028-K11@7.j...
# FA183D027-J11  [{'path': 'FA/18/3D/02/7J/11/FA183D027-J11@11....
# FA183D020-I11  [{'path': 'FA/18/3D/02/0I/11/FA183D020-I11@8.j...
#
#                      brand_name  is_premium  \
# sku
# LE213D004-K11           Levi's®       False
# AD116D0QW-I11  adidas Originals       False
# HA113G002-F11         Havaianas       False
# NI113D09V-A11   Nike Sportswear       False
# AD123K01P-K11  adidas Originals       False
# ...                         ...         ...
# EW383D04U-C11             Ewers       False
# JH186B00D-T11              Joha       False
# FA183D028-K11             Falke       False
# FA183D027-J11             Falke       False
# FA183D020-I11             Falke       False
#
#                                                  family_articles  \
# sku
# LE213D004-K11  [{'sku': 'LE213D004-K11', 'url_key': 'levisr-b...
# AD116D0QW-I11  [{'sku': 'AD116D0QW-I11', 'url_key': 'adidas-o...
# HA113G002-F11  [{'sku': 'HA113G002-F11', 'url_key': 'havaiana...
# NI113D09V-A11  [{'sku': 'NI113D09V-A11', 'url_key': 'nike-spo...
# AD123K01P-K11  [{'sku': 'AD123K01P-K11', 'url_key': 'adidas-o...
# ...                                                          ...
# EW383D04U-C11  [{'sku': 'EW383D04U-C11', 'url_key': 'ewers-st...
# JH186B00D-T11  [{'sku': 'JH186B00D-T11', 'url_key': 'joha-nig...
# FA183D028-K11  [{'sku': 'FA183D028-K11', 'url_key': 'falke-fa...
# FA183D027-J11  [{'sku': 'FA183D027-J11', 'url_key': 'falke-gl...
# FA183D020-I11  [{'sku': 'FA183D020-I11', 'url_key': 'falke-mu...
#
#                                                            flags  \
# sku
# LE213D004-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# AD116D0QW-I11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# HA113G002-F11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# NI113D09V-A11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# AD123K01P-K11  [{'key': 'campaign', 'value': '-15% EXTRA', 't...
# ...                                                          ...
# EW383D04U-C11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
# JH186B00D-T11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
# FA183D028-K11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
# FA183D027-J11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
# FA183D020-I11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...
#
#               product_group delivery_promises price.original  \
# sku
# LE213D004-K11          shoe                []        44,95 €
# AD116D0QW-I11          shoe                []        54,95 €
# HA113G002-F11          shoe                []        19,95 €
# NI113D09V-A11          shoe                []        89,95 €
# AD123K01P-K11      clothing                []        37,95 €
# ...                     ...               ...            ...
# EW383D04U-C11     underwear                []        20,95 €
# JH186B00D-T11     nightwear                []        24,95 €
# FA183D028-K11     underwear                []        17,95 €
# FA183D027-J11     underwear                []        12,95 €
# FA183D020-I11     underwear                []        13,95 €
#
#               price.promotional  price.has_different_prices  \
# sku
# LE213D004-K11           35,95 €                       False
# AD116D0QW-I11           41,45 €                       False
# HA113G002-F11           17,95 €                       False
# NI113D09V-A11           35,95 €                       False
# AD123K01P-K11           15,15 €                        True
# ...                         ...                         ...
# EW383D04U-C11           20,95 €                       False
# JH186B00D-T11           24,95 €                       False
# FA183D028-K11           17,95 €                       False
# FA183D027-J11           12,95 €                       False
# FA183D020-I11           13,95 €                       False
#
#                price.has_different_original_prices  \
# sku
# LE213D004-K11                                False
# AD116D0QW-I11                                False
# HA113G002-F11                                False
# NI113D09V-A11                                False
# AD123K01P-K11                                False
# ...                                            ...
# EW383D04U-C11                                False
# JH186B00D-T11                                False
# FA183D028-K11                                False
# FA183D027-J11                                False
# FA183D020-I11                                False
#
#                price.has_different_promotional_prices  \
# sku
# LE213D004-K11                                   False
# AD116D0QW-I11                                   False
# HA113G002-F11                                   False
# NI113D09V-A11                                   False
# AD123K01P-K11                                    True
# ...                                               ...
# EW383D04U-C11                                   False
# JH186B00D-T11                                   False
# FA183D028-K11                                   False
# FA183D027-J11                                   False
# FA183D020-I11                                   False
#
#                price.has_discount_on_selected_sizes_only  \
# sku
# LE213D004-K11                                      False
# AD116D0QW-I11                                      False
# HA113G002-F11                                      False
# NI113D09V-A11                                      False
# AD123K01P-K11                                      False
# ...                                                  ...
# EW383D04U-C11                                      False
# JH186B00D-T11                                      False
# FA183D028-K11                                      False
# FA183D027-J11                                      False
# FA183D020-I11                                      False
#
#                     tracking_information.metrigo_impression_urls  \
# sku
# LE213D004-K11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# AD116D0QW-I11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# HA113G002-F11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# NI113D09V-A11                                                NaN
# AD123K01P-K11                                                NaN
# ...                                                          ...
# EW383D04U-C11                                                NaN
# JH186B00D-T11                                                NaN
# FA183D028-K11                                                NaN
# FA183D027-J11                                                NaN
# FA183D020-I11                                                NaN
#
#                           tracking_information.impression_beacon  \
# sku
# LE213D004-K11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# AD116D0QW-I11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# HA113G002-F11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# NI113D09V-A11                                                NaN
# AD123K01P-K11                                                NaN
# ...                                                          ...
# EW383D04U-C11                                                NaN
# JH186B00D-T11                                                NaN
# FA183D028-K11                                                NaN
# FA183D027-J11                                                NaN
# FA183D020-I11                                                NaN
#
#               tracking_information.source amount
# sku
# LE213D004-K11                         ccp    NaN
# AD116D0QW-I11                         ccp    NaN
# HA113G002-F11                         ccp    NaN
# NI113D09V-A11                         NaN    NaN
# AD123K01P-K11                         NaN    NaN
# ...                                   ...    ...
# EW383D04U-C11                         NaN    NaN
# JH186B00D-T11                         NaN    NaN
# FA183D028-K11                         NaN    NaN
# FA183D027-J11                         NaN    NaN
# FA183D020-I11                         NaN    NaN
#
# [28629 rows x 20 columns]

# %%
total_pages
# Out:
# 341

# %% [markdown]
# #### Display the trending brand in DataFrame

# %%
df.brand_name.value_counts().index[0]
# Out:
# 'Name it'

# %% [markdown]
# #### Display the brand with maximal total discount (sum of discounts on all goods)

# %%
#Our data is still text. Convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

# %%
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

# %%
total_disc=df1.groupby(['brand_name']).sum().discount_amount

# %%
total_disc.sort_values(ascending=False).index[0]
# Out:
# 'Scotch & Soda'

# %% [markdown]
# #### Display the brands without discount at all

# %%
total_disc[total_disc==0]
# Out:
# brand_name
# Angel & Rocket             0.0
# Be Only                    0.0
# Belstaff                   0.0
# Bikkembergs Kids           0.0
# Bogs                       0.0
# Bomboogie                  0.0
# Clarks                     0.0
# Craft                      0.0
# Disney Clarks              0.0
# Enter                      0.0
# Fabrizio                   0.0
# Finger in the nose         0.0
# Fjällräven                 0.0
# Hatley                     0.0
# Herschel                   0.0
# Hip                        0.0
# K-SWISS                    0.0
# KG by Kurt Geiger          0.0
# La Queue du Chat           0.0
# MP Denmark                 0.0
# Mini Molly                 0.0
# Modern Native              0.0
# NOP                        0.0
# Nike Golf                  0.0
# Nordic coast company       0.0
# ODLO                       0.0
# Outerstuff                 0.0
# Outfit Kids                0.0
# Patagonia                  0.0
# People Wear Organic        0.0
# Pinocchio                  0.0
# Play Up                    0.0
# Scotch R'Belle             0.0
# Sisley                     0.0
# Sonia Rykiel               0.0
# THE ANIMALS OBSERVATORY    0.0
# THE WHITE BRAND            0.0
# TOMS                       0.0
# Ten Cate                   0.0
# Uhlsport                   0.0
# Umbro                      0.0
# Unauthorized               0.0
# Vilebrequin                0.0
# XTI                        0.0
# Zoe Leggings               0.0
# bellybutton                0.0
# fullstop.                  0.0
# mtng                       0.0
# shoeb76                    0.0
# Name: discount_amount, dtype: float64
